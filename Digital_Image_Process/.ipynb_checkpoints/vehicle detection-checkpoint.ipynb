# %%
from sre_parse import TYPE_FLAGS
import cv2
import numpy as np
from tqdm import tqdm
import time

class GetVideo():
    def get_video_frames(self, filename):
        address = filename
        capture = cv2.VideoCapture(address)
        frames = []
        while capture.isOpened():
            run, frame = capture.read()
            if not run:
                break
            img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            frames.append(img)
        capture.release()
        return np.array(frames, dtype='uint8')

class ObjectDetection():
    # Frame RGB -> HSV
    def frames_rgb_to_hsv(self, frames):
        g_frames = []
        for frame in frames:
            g_frames.append(cv2.cvtColor(frame, cv2.COLOR_RGB2HSV))
        return np.array(g_frames, dtype='uint8')

    # Frame HSV -> RGB
    def frames_hsv_to_rgb(self, frames):
        g_frames = []
        for frame in frames:
            g_frames.append(cv2.cvtColor(frame, cv2.COLOR_HSV2RGB))
        return np.array(g_frames, dtype='uint8')

    # Delete Background
    def delete_background(self, frames):
        avg = np.zeros_like(frames[0], dtype='uint64')
        i = 0
        for frame in frames:
            i += 1
            avg += frame
        avg = np.array(avg / i, dtype='uint8')
        for j, frame in enumerate(frames):
            frames[j] = frame - avg
        return frames

    # Thresholding video
    def thresholding(self, frames, thres_min, thres_max):
        for i, frame in enumerate(frames):
            _, frames[i] = cv2.threshold(frame, thres_min, 255, cv2.THRESH_TOZERO)
            _, frames[i] = cv2.threshold(frame, thres_max, 0, cv2.THRESH_TOZERO_INV)
        return frames


    # Connect Components
    def connect_components(self, frames, original_frames, area_min, road_hue_threshold=15):
        for k, frame in enumerate(frames):
            cnt, labels, stats, centroids = cv2.connectedComponentsWithStats(frame[:, :, 2])
            
            # 도로 색상 추출
            road_hues = []
            for i in range(1, cnt):
                (x, y, w, h, area) = stats[i]
                road_roi = frame[y:y+h, x:x+w, :]
                road_hue = np.mean(road_roi[:, :, 0])
                road_hues.append(road_hue)
            
            # 도로 색상 평균 계산
            road_hue_mean = np.mean(road_hues)
            
             # 자동차와 그림자 구분
            car_boxes = []  # 자동차 박스 좌표
            for i in range(1, cnt):
                (x, y, w, h, area) = stats[i]
                if area < area_min:
                    continue
                road_hue = np.mean(road_roi[:, :, 0])
                
                if abs(road_hue - road_hue_mean) < road_hue_threshold:
                    continue
                else:
                    # 자동차로 판단하여 사각형 그리기
                    car_boxes.append((x, y, w, h))
            
            # 중복 제거된 자동차 사각형 그리기
            for car_box in car_boxes:
                (x, y, w, h) = car_box
                if w > 2.5 * h:
                    continue
                else:
                    cv2.rectangle(original_frames[k], (x, y), (x + w, y + h), (0, 0, 255), 2)
            
        return original_frames


    # Vehicle Detection
    def vehicle_detection(self, frames):
        hsv_frames = self.frames_rgb_to_hsv(frames)
        back_deleted_frames = self.delete_background(hsv_frames[:, :, :, 2].copy())
        hsv_frames[:, :, :, 2] = self.thresholding(back_deleted_frames, 30, 230)
        hsv_frames = self.frames_hsv_to_rgb(hsv_frames)
        connected_frames = self.connect_components(hsv_frames, frames, 180)
        return connected_frames

# 비디오 파일명
video_filename = "car.mp4"

# GetVideo 클래스 인스턴스 생성
video_reader = GetVideo()

# 비디오 프레임 추출
frames = video_reader.get_video_frames(video_filename)

# ObjectDetection 클래스 인스턴스 생성
object_detector = ObjectDetection()

# 차량 탐지
result_frames = object_detector.vehicle_detection(frames)

# 결과 동영상 보여주기
for frame in result_frames:
    cv2.imshow("Car Detection", frame)
    if cv2.waitKey(25) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
