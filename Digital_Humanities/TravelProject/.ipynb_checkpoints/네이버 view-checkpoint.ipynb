# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

driver = webdriver.Chrome()
driver.get('https://search.naver.com/search.naver?where=view&query=%EC%A0%9C%EC%A3%BC%EC%8B%9C%20%ED%95%B4%EC%88%98%EC%9A%95%EC%9E%A5&sm=tab_opt&nso=so%3Add%2Cp%3A1y%2Ca%3Aall&mode=normal&main_q=&st_coll=&topic_r_cat=')
time.sleep(1)
while True:
    old_height = driver.execute_script('return window.pageYOffset')
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    now_height = driver.execute_script('return window.pageYOffset')
    if now_height == old_height:
        break
title = driver.find_elements(By.CSS_SELECTOR, '#main_pack > section > div > div._list > panel-list > div:nth-child(1) > more-contents > div > ul > li:nth-child(1) > div.total_wrap.api_ani_send > div > a')
titletext = []
for i in title:
    titletext.append(i.text)
    
alltitle = " ".join(titletext)
f = open("제주시_해수욕장.txt", 'w')
f.write(alltitle)
f.close()

from kiwipiepy import Kiwi
import pandas as pd
import re

kiwi = Kiwi()
kiwi.load_user_dictionary('user_dictionary.txt')
kiwi.prepare()
def extract_noun(text):
    result = kiwi.tokenize(text)
    for token in result:
        if token.tag in ['NNG', 'NNP']:
            yield token.form
title = open('제주시_해수욕장.txt', encoding = 'UTF-8').read()
title = re.sub('[^가-힣]', '', title)
titlelist = list(extract_noun(title))
topwords = pd.Series(titlelist).value_counts()
topwords.to_csv("제주시_해수욕장.csv")

# %%
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException

driver = webdriver.Chrome()
driver.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=view&query=%EC%84%9C%EA%B7%80%ED%8F%AC%EC%8B%9C+%ED%95%B4%EC%88%98%EC%9A%95%EC%9E%A5&oquery=%EC%A0%9C%EC%A3%BC%EC%8B%9C+%ED%95%B4%EC%88%98%EC%9A%95%EC%9E%A5&tqi=ic9h1dp0J14ssPc35E8ssssstzh-438092&nso=so%3Ar%2Cp%3A1y&mode=normal')
time.sleep(1)
while True:
    old_height = driver.execute_script('return window.pageYOffset')
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
    now_height = driver.execute_script('return window.pageYOffset')
    if now_height == old_height:
        break
title = driver.find_elements(By.CSS_SELECTOR, '#main_pack > section > div > div._list > panel-list > div > more-contents > div > ul')
titletext = []
for i in title:
    titletext.append(i.text)
    
alltitle = " ".join(titletext)
f = open("서귀포시_해수욕장.txt", 'w')
f.write(alltitle)
f.close()

from kiwipiepy import Kiwi
import pandas as pd
import re

kiwi = Kiwi()
kiwi.load_user_dictionary('user_dictionary.txt')
kiwi.prepare()
def extract_noun(text):
    result = kiwi.tokenize(text)
    for token in result:
        
        if token.tag in ['NNG', 'NNP']:
            yield token.form
title = open('서귀포시_해수욕장.txt', encoding = 'UTF-8').read()
title = re.sub('[^가-힣]', '', title)
titlelist = list(extract_noun(title))
topwords = pd.Series(titlelist).value_counts()
topwords.to_csv("서귀포시_해수욕장.csv")

# %%
import requests
from bs4 import BeautifulSoup
import csv
f = open('write.csv','w', newline='', encoding='utf-8-sig')
wr = csv.writer(f) 

url = 'https://search.naver.com/search.naver?where=view&query=%EC%84%9C%EA%B7%80%ED%8F%AC%EC%8B%9C%20%ED%95%B4%EC%88%98%EC%9A%95%EC%9E%A5&sm=tab_opt&nso=so%3Ar%2Cp%3A1y%2Ca%3Aall&mode=normal&main_q=&st_coll=&topic_r_cat='
headers = {"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
response = requests.get(url, headers=headers)
html = response.text
soup = BeautifulSoup(html, 'html.parser')
title=soup.select('#main_pack > section > div > div._list > panel-list > div > more-contents > div > ul > li > div > div > a')

titletext = []
for i in title:
    titletext.append(i.text)
alltitle = " ".join(titletext)
f = open("서귀포시_해수욕장_제목.txt", 'w')
f.write(alltitle)
f.close()

from kiwipiepy import Kiwi
import pandas as pd
import re

kiwi = Kiwi()
kiwi.load_user_dictionary('user_dictionary.txt')
kiwi.prepare()
def extract_noun(text):
    result = kiwi.tokenize(text)
    for token in result:
        if token.tag in ['NNG', 'NNP']:
            yield token.form
title = open('서귀포시_해수욕장_제목.txt', encoding = 'UTF-8').read()
title = re.sub('[^가-힣]', '', title)
titlelist = list(extract_noun(title))
topwords = pd.Series(titlelist).value_counts()
topwords.to_csv("서귀포시_해수욕장_제목.csv")

# %%
import requests
from bs4 import BeautifulSoup
import csv
f = open('write.csv','w', newline='', encoding='utf-8-sig')
wr = csv.writer(f) 

url = 'https://search.naver.com/search.naver?where=view&query=%EC%A0%9C%EC%A3%BC%EC%8B%9C%20%ED%95%B4%EC%88%98%EC%9A%95%EC%9E%A5&sm=tab_opt&nso=so%3Ar%2Cp%3A1y&mode=normal&main_q=&st_coll=&topic_r_cat='
headers = {"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36"}
response = requests.get(url, headers=headers)
html = response.text
soup = BeautifulSoup(html, 'html.parser')
title=soup.select('#main_pack > section > div > div._list > panel-list > div > more-contents > div > ul > li > div > div > a')

titletext = []
for i in title:
    titletext.append(i.text)
alltitle = " ".join(titletext)
f = open("제주시_해수욕장_제목.txt", 'w')
f.write(alltitle)
f.close()

from kiwipiepy import Kiwi
import pandas as pd
import re

kiwi = Kiwi()
kiwi.load_user_dictionary('user_dictionary.txt')
kiwi.prepare()
def extract_noun(text):
    result = kiwi.tokenize(text)
    for token in result:
        if token.tag in ['NNG', 'NNP']:
            yield token.form
title = open('제주시_해수욕장_제목.txt', encoding = 'UTF-8').read()
title = re.sub('[^가-힣]', '', title)
titlelist = list(extract_noun(title))
topwords = pd.Series(titlelist).value_counts()
topwords.to_csv("제주시_해수욕장_제목.csv")
